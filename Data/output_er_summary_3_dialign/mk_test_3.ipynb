# %%
import numpy as np
import pymannkendall as mk
import pandas as pd
import glob,os
import statsmodels.api as sm
from scipy import stats
from matplotlib import pyplot as plt

# %%
er_file = glob.glob("S***.csv")

# %%
dl_er = []
out = []
for f in er_file:
    dl_er.append(pd.read_csv(f))

for x in dl_er:
    print(len(x))
    if len(x)>8:
        x = x.drop(index=[len(x)-1])
        out.append(mk.original_test(x['av_er_ratio']))
# Out:
# 22
# 25
# 10
# 22
# 61
# 27
# 27
# 38
# 28
# 10
# 15
# 28
# 47
# 11
# 78
# 14
# 23
# 15
# 9
# 11
# 17
# 4
# 30
# 14
# 21
# 35
# 30
# 41
# 19
# 11
# 69
# 20
# 11
# 5
# 51
# 17
# 10
# 10
# 27
# 10
# 28
# 34
# 33
# 22
# 24
# 19
# 24
# 22
# 9
# 42
# 21
# 22
# 25
# 7
# 43
# 16
# 32
# 12
# 17
# 12
# 53
# 11
# 72
# 49
# 5
# 30
# 8
# 5
# 51
# 13
# 12
# 11
# 10
# 5
# 14
# 10
# 32
# 6
# 14
# 12
# 5
# 28
# 10
# 9
# 29
# 18
# 20
# 61
# 28
# 6
# 21
# 6
# 9
# 27
# 10
# 17
# 49
# 16
# 11
# 13
# 11
# 33
# 6
# 8
# 8
# 15
# 56
# 9
# 52
# 11
# 7
# 7
# 28
# 12
# 19
# 8
# 56
# 4
# 4
# 8
# 32
# 14
# 20
# 9
# 55
# 8
# 64
# 5
# 12
# 17
# 5
# 50
# 6
# 20
# 50
# 14
# 8
# 4
# 9
# 24
# 10
# 10
# 51
# 8
# 11
# 10
# 27
# 42
# 40
# 30
# 9
# 8
# 21
# 43
# 76
# 40
# 60
# 23
# 11
# 5
# 6
# 13
# 15
# 56
# 30
# 14
# 7
# 11
# 4
# 17
# 7
# 41
# 5
# 6
# 5
# 10
# 6
# 33
# 47
# 12
# 16
# 20
# 33
# 10
# 16
# 27
# 17
# 5
# 19
# 16
# 46
# 4
# 14
# 11
# 14
# 8
# 36
# 5
# 5
# 22
# 18
# 6
# 10
# 7
# 20
# 7
# 34
# 21
# 22
# 25
# 11
# 2
# 11
# 35
# 20
# 50
# 15
# 44
# 12
# 8
# 7
# 11
# 16
# 35
# 7
# 7
# 14
# 18
# 20
# 7
# 14
# 34
# 11
# 14
# 25
# 104
# 24
# 26
# 17
# 10
# 6
# 9
# 22
# 9
# 12
# 19
# 45
# 15
# 22
# 9
# 21
# 25
# 4
# 16
# 44
# 8
# 8
# 19
# 36
# 20
# 17
# 9
# 8
# 32
# 17
# 4
# 6
# 24
# 90
# 14
# 20
# 49
# 14
# 21
# 38
# 15
# 10
# 7
# 8
# 13
# 54
# 11
# 15
# 13
# 38
# 11
# 20
# 6
# 19
# 34
# 5
# 7
# 11
# 30
# 17
# 12
# 25
# 10
# 6
# 40
# 21
# 8
# 26
# 29
# 20
# 36
# 9
# 61
# 7
# 4
# 48
# 10
# 67
# 27
# 5
# 5
# 12
# 7
# 13
# 12
# 11
# 31
# 17
# 25
# 29
# 16
# 29
# 13
# 43
# 20
# 10
# 10
# 13
# 16

# %%
df = pd.concat(dl_er)
df.to_csv('group3_summary.csv', index = False)

# %%
df_summary = pd.read_csv('group3_summary.csv')

# %%
print(df_summary)
# Out:
#      speaker1  speaker1_token_number  speaker1_expression_token_number  \
# 0       S0257                    397                                70
# 1       S0257                    209                                58
# 2       S0257                    156                               103
# 3       S0257                    154                                92
# 4       S0257                     61                                45
# ...       ...                    ...                               ...
# 6938    S0326                      3                                 3
# 6939    S0326                    130                               104
# 6940    S0326                    233                               192
# 6941    S0326                    124                               102
# 6942    S0326                     41                                31
#
#       speaker1_expression_number  speaker1_er_ratio speaker2  \
# 0                             69           0.176322    S0258
# 1                             54           0.277512    S0258
# 2                             88           0.660256    S0258
# 3                             78           0.597403    S0258
# 4                             37           0.737705    S0258
# ...                          ...                ...      ...
# 6938                           2           1.000000    S0382
# 6939                          74           0.800000    S0382
# 6940                         150           0.824034    S0382
# 6941                          83           0.822581    S0382
# 6942                          25           0.756098    S0382
#
#       speaker2_token_number  speaker2_expression_token_number  \
# 0                        24                                 4
# 1                        38                                17
# 2                       100                                74
# 3                       193                               141
# 4                       139                               103
# ...                     ...                               ...
# 6938                    402                               289
# 6939                    277                               215
# 6940                    122                               100
# 6941                    158                               131
# 6942                    113                                99
#
#       speaker2_expression_number  speaker2_er_ratio  ...  \
# 0                              4           0.166667  ...
# 1                             14           0.447368  ...
# 2                             63           0.740000  ...
# 3                            108           0.730570  ...
# 4                             84           0.741007  ...
# ...                          ...                ...  ...
# 6938                         238           0.718905  ...
# 6939                         169           0.776173  ...
# 6940                          76           0.819672  ...
# 6941                          97           0.829114  ...
# 6942                          70           0.876106  ...
#
#      speaker3_expression_token_number  speaker3_expression_number  \
# 0                                  14                          11
# 1                                  57                          46
# 2                                 120                         102
# 3                                  28                          22
# 4                                 130                         106
# ...                               ...                         ...
# 6938                              144                         105
# 6939                               65                          42
# 6940                               49                          34
# 6941                               90                          63
# 6942                               69                          55
#
#       speaker3_er_ratio  total_token_number  total_er_token_number  \
# 0              0.424242                 454                     88
# 1              0.740260                 324                    132
# 2              0.705882                 426                    297
# 3              0.823529                 381                    261
# 4              0.751445                 373                    278
# ...                 ...                 ...                    ...
# 6938           0.852071                 574                    436
# 6939           0.915493                 478                    384
# 6940           0.960784                 406                    341
# 6941           0.849057                 388                    323
# 6942           0.811765                 239                    199
#
#       av_er_ratio  total_er_number  begin  end      file
# 0        0.193833               84      0   50  S539.tsv
# 1        0.407407              114     50  100  S539.tsv
# 2        0.697183              253    100  150  S539.tsv
# 3        0.685039              208    150  200  S539.tsv
# 4        0.745308              227    200  250  S539.tsv
# ...           ...              ...    ...  ...       ...
# 6938     0.759582              345    550  600  SNQD.tsv
# 6939     0.803347              285    600  650  SNQD.tsv
# 6940     0.839901              260    650  700  SNQD.tsv
# 6941     0.832474              243    700  750  SNQD.tsv
# 6942     0.832636              150    750  796  SNQD.tsv
#
# [6943 rows x 22 columns]

# %%
import seaborn as sns

for i in range(0, len(df_summary)):
    if df_summary['end'].iloc[i]%50!=0:
        df_summary['av_er_ratio'].iloc[i] = None

df_summary = df_summary.dropna()
print(df_summary.head())
# Out:
#   speaker1  speaker1_token_number  speaker1_expression_token_number  \
# 0    S0257                    397                                70
# 1    S0257                    209                                58
# 2    S0257                    156                               103
# 3    S0257                    154                                92
# 4    S0257                     61                                45
#
#    speaker1_expression_number  speaker1_er_ratio speaker2  \
# 0                          69           0.176322    S0258
# 1                          54           0.277512    S0258
# 2                          88           0.660256    S0258
# 3                          78           0.597403    S0258
# 4                          37           0.737705    S0258
#
#    speaker2_token_number  speaker2_expression_token_number  \
# 0                     24                                 4
# 1                     38                                17
# 2                    100                                74
# 3                    193                               141
# 4                    139                               103
#
#    speaker2_expression_number  speaker2_er_ratio  ...  \
# 0                           4           0.166667  ...
# 1                          14           0.447368  ...
# 2                          63           0.740000  ...
# 3                         108           0.730570  ...
# 4                          84           0.741007  ...
#
#   speaker3_expression_token_number  speaker3_expression_number  \
# 0                               14                          11
# 1                               57                          46
# 2                              120                         102
# 3                               28                          22
# 4                              130                         106
#
#    speaker3_er_ratio  total_token_number  total_er_token_number  av_er_ratio  \
# 0           0.424242                 454                     88     0.193833
# 1           0.740260                 324                    132     0.407407
# 2           0.705882                 426                    297     0.697183
# 3           0.823529                 381                    261     0.685039
# 4           0.751445                 373                    278     0.745308
#
#    total_er_number  begin  end      file
# 0               84      0   50  S539.tsv
# 1              114     50  100  S539.tsv
# 2              253    100  150  S539.tsv
# 3              208    150  200  S539.tsv
# 4              227    200  250  S539.tsv
#
# [5 rows x 22 columns]

# %%
sns.set_theme(style="darkgrid")
sns.lineplot(x=df_summary['end'], y=df_summary['av_er_ratio'])

# %%
for i in range(0, len(df_summary)):
    if df_summary['end'].iloc[i]%50!=0:
        df_summary['av_er_ratio'].iloc[i] = None

df_summary = df_summary.dropna()

grouped_df = df_summary.groupby("end")
mean_df = grouped_df['av_er_ratio'].mean()

mean_df = mean_df.reset_index()
print(mean_df)
# Out:
#       end  av_er_ratio
# 0      50     0.341466
# 1     100     0.556707
# 2     150     0.642617
# 3     200     0.689456
# 4     250     0.722701
# ..    ...          ...
# 98   4950     0.918079
# 99   5000     0.932099
# 100  5050     0.919048
# 101  5100     0.915344
# 102  5150     0.917671
#
# [103 rows x 2 columns]
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
import matplotlib.pyplot as plt
l1=plt.plot(mean_df['end'],mean_df['av_er_ratio'],label='type1')
plt.title('The Average ER ratio at each position - 3 speakers - method1')
plt.xlabel('Position')
plt.ylabel('Average ER ratio')
# Out:
# Text(0, 0.5, 'Average ER ratio')

# %%
print(len(dl_er))
print(len(out))
c = 0
for o in out:
    if o.trend == "increasing":
        c = c+1
print(c)
print(263/264)
# Out:
# 334
# 264
# 263
# 0.9962121212121212

# %%
res = []
for x in dl_er:
    if len(x)>8:
        x = x.drop(index=[len(x)-1])
        mod = sm.GLM(x['av_er_ratio'], x['end'], family=sm.families.Gaussian(sm.families.links.log))
        res.append(mod.fit())
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Calling Family(..) with a link class as argument is deprecated.
# Use an instance of a link class instead.
#   """

# %%
for r in res:
    print(r.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            av_er_ratio   No. Observations:                   21
# Model:                            GLM   Df Residuals:                       20
# Model Family:                Gaussian   Df Model:                            0
# Link Function:                    log   Scale:                        0.049131
# Method:                          IRLS   Log-Likelihood:                 2.3415
# Date:                Mon, 03 May 2021   Deviance:                      0.98263
# Time:                        05:01:57   Pearson chi2:                    0.983
# No. Iterations:                     7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# end           -0.0005      0.000     -4.392      0.000      -0.001      -0.000
# ==============================================================================
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            av_er_ratio   No. Observations:                   24
# Model:                            GLM   Df Residuals:                       23
# Model Family:                Gaussian   Df Model:                            0
# Link Function:                    log   Scale:                        0.046649
# Method:                          IRLS   Log-Likelihood:                 3.2268
# Date:                Mon, 03 May 2021   Deviance:                       1.0729
# Time:                        05:01:57   Pearson chi2:                     1.07
# No. Iterations:                     7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# end           -0.0005   9.24e-05     -4.904      0.000      -0.001      -0.000
# ==============================================================================
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            av_er_ratio   No. Observations:                    9
# Model:                            GLM   Df Residuals:                        8
# Model Family:                Gaussian   Df Model:                            0
# Link Function:                    log   Scale:                        0.058957
# Method:                          IRLS   Log-Likelihood:                0.46883
# Date:                Mon, 03 May 2021   Deviance:                      0.47165
# Time:                        05:01:57   Pearson chi2:                    0.472
# No. Iterations:                     7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# end           -0.0015      0.000     -3.161      0.002      -0.002      -0.001
# ==============================================================================
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            av_er_ratio   No. Observations:                   21
# Model:                            GLM   Df Residuals:                       20
# Model Family:                Gaussian   Df Model:                            0
# Link Function:                    log   Scale:                        0.036817
# Method:                          IRLS   Log-Likelihood:                 5.3712
# Date:                Mon, 03 May 2021   Deviance:                      0.73634
# Time:                        05:01:57   Pearson chi2:                    0.736
# No. Iterations:                     7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# end           -0.0004   9.43e-05     -4.673      0.000      -0.001      -0.000
# ==============================================================================
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            av_er_ratio   No. Observations:                   60
# Model:                            GLM   Df Residuals:                       59
# Model Family:                Gaussian   Df Model:                            0
# Link Function:                    log   Scale:                        0.034316
# Method:                          IRLS   Log-Likelihood:                 16.528
# Date:                Mon, 03 May 2021   Deviance:                       2.0246
# Time:                        05:01:57   Pearson chi2:                     2.02
# No. Iterations:                     7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# end           -0.0001   1.83e-05     -7.268      0.000      -0.000   -9.73e-05
# ==============================================================================
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            av_er_ratio   No. Observations:                   26
# Model:                            GLM   Df Residuals:                       25
# Model Family:                Gaussian   Df Model:                            0
# Link Function:                    log   Scale:                        0.043416
# Method:                          IRLS   Log-Likelihood:                 4.3875
# Date:                Mon, 03 May 2021   Deviance:                       1.0854
# Time:                        05:01:57   Pearson chi2:                     1.09
# No. Iterations:                     7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# end           -0.0004   7.83e-05     -5.183      0.000      -0.001      -0.000
# ==============================================================================
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            av_er_ratio   No. Observations:                   26
# Model:                            GLM   Df Residuals:                       25
# Model Family:                Gaussian   Df Model:                            0
# Link Function:                    log   Scale:                        0.050648
# Method:                          IRLS   Log-Likelihood:                 2.3848
# Date:                Mon, 03 May 2021   Deviance:                       1.2662
# Time:                        05:01:57   Pearson chi2:                     1.27
# No. Iterations:                     7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# end           -0.0004   8.34e-05     -4.691      0.000      -0.001      -0.000
# ==============================================================================
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            av_er_ratio   No. Observations:                   37
# Model:                            GLM   Df Residuals:                       36
# Model Family:                Gaussian   Df Model:                            0
# Link Function:                    log   Scale:                        0.034317
# Method:                          IRLS   Log-Likelihood:                 10.384
# Date:                Mon, 03 May 2021   Deviance:                       1.2354
# Time:                        05:01:57   Pearson chi2:                     1.24
# No. Iterations:                     7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# end           -0.0002   3.74e-05     -5.660      0.000      -0.000      -0.000
# ==============================================================================
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            av_er_ratio   No. Observations:                   27
# Model:                            GLM   Df Residuals:                       26
# Model Family:                Gaussian   Df Model:                            0
# Link Function:                    log   Scale:                        0.032798
# Method:                          IRLS   Log-Likelihood:                 8.3235
# Date:                Mon, 03 May 2021   Deviance:                      0.85274
# Time:                        05:01:57   Pearson chi2:                    0.853
# No. Iterations:                     6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# end           -0.0003   5.87e-05     -5.063      0.000      -0.000      -0.000
# ==============================================================================
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            av_er_ratio   No. Observations:                    9
# Model:                            GLM   Df Residuals:                        8
# Model Family:                Gaussian   Df Model:                            0
# Link Function:                    log   Scale:                        0.036863
# Method:                          IRLS   Log-Likelihood:                 2.5820
# Date:                Mon, 03 May 2021   Deviance:                      0.29490
# Time:                        05:01:57   Pearson chi2:                    0.295
# No. Iterations:                     7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# end           -0.0015      0.000     -3.918      0.000      -0.002      -0.001
# ==============================================================================
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            av_er_ratio   No. Observations:                   14
# Model:                            GLM   Df Residuals:                       13
# Model Family:                Gaussian   Df Model:                            0
# Link Function:                    log   Scale:                        0.042317
# Method:                          IRLS   Log-Likelihood:                 2.7728
# Date:                Mon, 03 May 2021   Deviance:                      0.55013
# Time:                        05:01:57   Pearson chi2:                    0.550
# No. Iterations:                     7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# end           -0.0009      0.000     -4.293      0.000      -0.001      -0.000
# ==============================================================================
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            av_er_ratio   No. Observations:                   27
# Model:                            GLM   Df Residuals:                       26
# Model Family:                Gaussian   Df Model:                            0
# Link Function:                    log   Scale:                        0.082995
# Method:                          IRLS   Log-Likelihood:                -4.2102
# Date:                Mon, 03 May 2021   Deviance:                       2.1579
# Time:                        05:01:57   Pearson chi2:                     2.16
# No. Iterations:                     7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# end           -0.0005      0.000     -4.478      0.000      -0.001      -0.000
# ==============================================================================
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            av_er_ratio   No. Observations:                   46
# Model:                            GLM   Df Residuals:                       45
# Model Family:                Gaussian   Df Model:                            0
# Link Function:                    log   Scale:                        0.066961
# Method:                          IRLS   Log-Likelihood:                -2.5873
# Date:                Mon, 03 May 2021   Deviance:                       3.0132
# Time:                        05:01:57   Pearson chi2:                     3.01
# No. Iterations:                     8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# end           -0.0003   4.61e-05     -6.312      0.000      -0.000      -0.000
# ==============================================================================
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            av_er_ratio   No. Observations:                   10
# Model:                            GLM   Df Residuals:                        9
# Model Family:                Gaussian   Df Model:                            0
# Link Function:                    log   Scale:                        0.043204
# Method:                          IRLS   Log-Likelihood:                 2.0197
# Date:                Mon, 03 May 2021   Deviance:                      0.38884
# Time:                        05:01:57   Pearson chi2:                    0.389
# No. Iterations:                     7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# end           -0.0015      0.000     -4.061      0.000      -0.002      -0.001
# ==============================================================================
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            av_er_ratio   No. Observations:                   77
# Model:                            GLM   Df Residuals:                       76
# Model Family:                Gaussian   Df Model:                            0
# Link Function:                    log   Scale:                        0.023559
# Method:                          IRLS   Log-Likelihood:                 35.550
# Date:                Mon, 03 May 2021   Deviance:                       1.7905
# Time:                        05:01:57   Pearson chi2:                     1.79
# No. Iterations:                     6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# end        -9.116e-05   1.01e-05     -9.019      0.000      -0.000   -7.14e-05
# ==============================================================================
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            av_er_ratio   No. Observations:                   13
# Model:                            GLM   Df Residuals:                       12
# Model Family:                Gaussian   Df Model:                            0
# Link Function:                    log   Scale:                        0.037300
# Method:                          IRLS   Log-Likelihood:                 3.4307
# Date:                Mon, 03 May 2021   Deviance:                      0.44760
# Time:                        05:01:57   Pearson chi2:                    0.448
# No. Iterations:                     7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# end           -0.0008      0.000     -4.004      0.000      -0.001      -0.000
# ==============================================================================
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            av_er_ratio   No. Observations:                   22
# Model:                            GLM   Df Residuals:                       21
# Model Family:                Gaussian   Df Model:                            0
# Link Function:                    log   Scale:                         0.16092
# Method:                          IRLS   Log-Likelihood:                -10.621
# Date:                Mon, 03 May 2021   Deviance:                       3.3793
# Time:                        05:01:57   Pearson chi2:                     3.38
# No. Iterations:                    13
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# end           -0.0014      0.000     -3.682      0.000      -0.002      -0.001
# ==============================================================================
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            av_er_ratio   No. Observations:                   14
# Model:                            GLM   Df Residuals:                       13
# Model Family:                Gaussian   Df Model:                            0
# Link Function:                    log   Scale:                        0.060429
# Method:                          IRLS   Log-Likelihood:                0.27890
# Date:                Mon, 03 May 2021   Deviance:                      0.78557
# Time:                        05:01:57   Pearson chi2:                    0.786
# No. Iterations:                     7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# end           -0.0009      0.000     -3.646      0.000      -0.001      -0.000
# ==============================================================================
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            av_er_ratio   No. Observations:                    8
# Model:                            GLM   Df Residuals:                        7
# Model Family:                Gaussian   Df Model:                            0
# Link Function:                    log   Scale:                        0.051363
# Method:                          IRLS   Log-Likelihood:                 1.0238
# Date:                Mon, 03 May 2021   Deviance:                      0.35954
# Time:                        05:01:57   Pearson chi2:                    0.360
# No. Iterations:                     7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# end           -0.0014      0.000     -2.884      0.004      -0.002      -0.000
# ==============================================================================
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            av_er_ratio   No. Observations:                   10
# Model:                            GLM   Df Residuals:                        9
# Model Family:                Gaussian   Df Model:                            0
# Link Function:                    log   Scale:                        0.031769
# Method:                          IRLS   Log-Likelihood:                 3.5570
# Date:                Mon, 03 May 2021   Deviance:                      0.28592
# Time:                        05:01:57   Pearson chi2:                    0.286
# No. Iterations:                     7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# end           -0.0010      0.000     -3.858      0.000      -0.002      -0.001
# ==============================================================================
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            av_er_ratio   No. Observations:                   16
# Model:                            GLM   Df Residuals:                       15
# Model Family:                Gaussian   Df Model:                            0
# Link Function:                    log   Scale:                        0.044850
# Method:                          IRLS   Log-Likelihood:                 2.6323
# Date:                Mon, 03 May 2021   Deviance:                      0.67276
# Time:                        05:01:57   Pearson chi2:                    0.673
# No. Iterations:                     7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# end           -0.0006      0.000     -3.727      0.000      -0.001      -0.000
# ==============================================================================
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            av_er_ratio   No. Observations:                   29
# Model:                            GLM   Df Residuals:                       28
# Model Family:                Gaussian   Df Model:                            0
# Link Function:                    log   Scale:                        0.028167
# Method:                          IRLS   Log-Likelihood:                 11.110
# Date:                Mon, 03 May 2021   Deviance:                      0.78867
# Time:                        05:01:57   Pearson chi2:                    0.789
# No. Iterations:                     6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# end           -0.0003   4.95e-05     -5.807      0.000      -0.000      -0.000
# ==============================================================================
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            av_er_ratio   No. Observations:                   13
# Model:                            GLM   Df Residuals:                       12
# Model Family:                Gaussian   Df Model:                            0
# Link Function:                    log   Scale:                        0.039029
# Method:                          IRLS   Log-Likelihood:                 3.1362
# Date:                Mon, 03 May 2021   Deviance:                      0.46835
# Time:                        05:01:57   Pearson chi2:                    0.468
# No. Iterations:                     7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# end           -0.0007      0.000     -3.692      0.000      -0.001      -0.000
# ==============================================================================
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            av_er_ratio   No. Observations:                   20
# Model:                            GLM   Df Residuals:                       19
# Model Family:                Gaussian   Df Model:                            0
# Link Function:                    log   Scale:                        0.035295
# Method:                          IRLS   Log-Likelihood:                 5.5614
# Date:                Mon, 03 May 2021   Deviance:                      0.67060
# Time:                        05:01:57   Pearson chi2:                    0.671
# No. Iterations:                     7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# end           -0.0005   9.83e-05     -4.585      0.000      -0.001      -0.000
# ==============================================================================
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            av_er_ratio   No. Observations:                   34
# Model:                            GLM   Df Residuals:                       33
# Model Family:                Gaussian   Df Model:                            0
# Link Function:                    log   Scale:                        0.022218
# Method:                          IRLS   Log-Likelihood:                 16.973
# Date:                Mon, 03 May 2021   Deviance:                      0.73318
# Time:                        05:01:57   Pearson chi2:                    0.733
# No. Iterations:                     6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# end           -0.0002   3.39e-05     -6.647      0.000      -0.000      -0.000
# ==============================================================================
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            av_er_ratio   No. Observations:                   29
# Model:                            GLM   Df Residuals:                       28
# Model Family:                Gaussian   Df Model:                            0
# Link Function:                    log   Scale:                        0.040672
# Method:                          IRLS   Log-Likelihood:                 5.7830
# Date:                Mon, 03 May 2021   Deviance:                       1.1388
# Time:                        05:01:57   Pearson chi2:                     1.14
# No. Iterations:                     6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# end           -0.0003   5.84e-05     -4.620      0.000      -0.000      -0.000
# ==============================================================================
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            av_er_ratio   No. Observations:                   40
# Model:                            GLM   Df Residuals:                       39
# Model Family:                Gaussian   Df Model:                            0
# Link Function:                    log   Scale:                        0.036032
# Method:                          IRLS   Log-Likelihood:                 10.209
# Date:                Mon, 03 May 2021   Deviance:                       1.4053
# Time:                        05:01:57   Pearson chi2:                     1.41
# No. Iterations:                     6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# end           -0.0002   3.39e-05     -5.629      0.000      -0.000      -0.000
# ==============================================================================
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            av_er_ratio   No. Observations:                   18
# Model:                            GLM   Df Residuals:                       17
# Model Family:                Gaussian   Df Model:                            0
# Link Function:                    log   Scale:                        0.061071
# Method:                          IRLS   Log-Likelihood:                0.12064
# Date:                Mon, 03 May 2021   Deviance:                       1.0382
# Time:                        05:01:57   Pearson chi2:                     1.04
# No. Iterations:                    26
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# end           -0.0044      0.001     -4.294      0.000      -0.006      -0.002
# ==============================================================================
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            av_er_ratio   No. Observations:                   10
# Model:                            GLM   Df Residuals:                        9
# Model Family:                Gaussian   Df Model:                            0
# Link Function:                    log   Scale:                        0.039171
# Method:                          IRLS   Log-Likelihood:                 2.5097
# Date:                Mon, 03 May 2021   Deviance:                      0.35254
# Time:                        05:01:57   Pearson chi2:                    0.353
# No. Iterations:                     7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# end           -0.0009      0.000     -3.255      0.001      -0.002      -0.000
# ==============================================================================
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            av_er_ratio   No. Observations:                   68
# Model:                            GLM   Df Residuals:                       67
# Model Family:                Gaussian   Df Model:                            0
# Link Function:                    log   Scale:                        0.056526
# Method:                          IRLS   Log-Likelihood:                 1.6959
# Date:                Mon, 03 May 2021   Deviance:                       3.7873
# Time:                        05:01:57   Pearson chi2:                     3.79
# No. Iterations:                     8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# end           -0.0002   2.33e-05     -8.169      0.000      -0.000      -0.000
# ==============================================================================
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            av_er_ratio   No. Observations:                   19
# Model:                            GLM   Df Residuals:                       18
# Model Family:                Gaussian   Df Model:                            0
# Link Function:                    log   Scale:                        0.067660
# Method:                          IRLS   Log-Likelihood:               -0.87391
# Date:                Mon, 03 May 2021   Deviance:                       1.2179
# Time:                        05:01:57   Pearson chi2:                     1.22
# No. Iterations:                     7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# end           -0.0006      0.000     -3.705      0.000      -0.001      -0.000
# ==============================================================================
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            av_er_ratio   No. Observations:                   10
# Model:                            GLM   Df Residuals:                        9
# Model Family:                Gaussian   Df Model:                            0
# Link Function:                    log   Scale:                        0.040401
# Method:                          IRLS   Log-Likelihood:                 2.3551
# Date:                Mon, 03 May 2021   Deviance:                      0.36361
# Time:                        05:01:57   Pearson chi2:                    0.364
# No. Iterations:                     7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# end           -0.0015      0.000     -4.218      0.000      -0.002      -0.001
# ==============================================================================
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            av_er_ratio   No. Observations:                   50
# Model:                            GLM   Df Residuals:                       49
# Model Family:                Gaussian   Df Model:                            0
# Link Function:                    log   Scale:                        0.024988
# Method:                          IRLS   Log-Likelihood:                 21.787
# Date:                Mon, 03 May 2021   Deviance:                       1.2244
# Time:                        05:01:57   Pearson chi2:                     1.22
# No. Iterations:                     7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# end           -0.0002   2.03e-05     -7.599      0.000      -0.000      -0.000
# ==============================================================================
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            av_er_ratio   No. Observations:                   16
# Model:                            GLM   Df Residuals:                       15
# Model Family:                Gaussian   Df Model:                            0
# Link Function:                    log   Scale:                        0.039141
# Method:                          IRLS   Log-Likelihood:                 3.7217
# Date:                Mon, 03 May 2021   Deviance:                      0.58711
# Time:                        05:01:57   Pearson chi2:                    0.587
# No. Iterations:                     7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# end           -0.0006      0.000     -4.262      0.000      -0.001      -0.000
# ==============================================================================
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            av_er_ratio   No. Observations:                    9
# Model:                            GLM   Df Residuals:                        8
# Model Family:                Gaussian   Df Model:                            0
# Link Function:                    log   Scale:                        0.036769
# Method:                          IRLS   Log-Likelihood:                 2.5935
# Date:                Mon, 03 May 2021   Deviance:                      0.29415
# Time:                        05:01:57   Pearson chi2:                    0.294
# No. Iterations:                     7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# end           -0.0012      0.000     -3.538      0.000      -0.002      -0.001
# ==============================================================================
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            av_er_ratio   No. Observations:                    9
# Model:                            GLM   Df Residuals:                        8
# Model Family:                Gaussian   Df Model:                            0
# Link Function:                    log   Scale:                        0.049785
# Method:                          IRLS   Log-Likelihood:                 1.2297
# Date:                Mon, 03 May 2021   Deviance:                      0.39828
# Time:                        05:01:57   Pearson chi2:                    0.398
# No. Iterations:                     7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# end           -0.0016      0.000     -3.538      0.000      -0.003      -0.001
# ==============================================================================
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            av_er_ratio   No. Observations:                   26
# Model:                            GLM   Df Residuals:                       25
# Model Family:                Gaussian   Df Model:                            0
# Link Function:                    log   Scale:                        0.042686
# Method:                          IRLS   Log-Likelihood:                 4.6082
# Date:                Mon, 03 May 2021   Deviance:                       1.0671
# Time:                        05:01:57   Pearson chi2:                     1.07
# No. Iterations:                     7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# end           -0.0004    7.6e-05     -5.036      0.000      -0.001      -0.000
# ==============================================================================
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            av_er_ratio   No. Observations:                    9
# Model:                            GLM   Df Residuals:                        8
# Model Family:                Gaussian   Df Model:                            0
# Link Function:                    log   Scale:                        0.049623
# Method:                          IRLS   Log-Likelihood:                 1.2444
# Date:                Mon, 03 May 2021   Deviance:                      0.39698
# Time:                        05:01:57   Pearson chi2:                    0.397
# No. Iterations:                     7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# end           -0.0012      0.000     -2.953      0.003      -0.002      -0.000
# ...
# Method:                          IRLS   Log-Likelihood:                 6.4878
# Date:                Mon, 03 May 2021   Deviance:                       1.1391
# Time:                        05:01:57   Pearson chi2:                     1.14
# No. Iterations:                     7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# end           -0.0003   5.78e-05     -5.427      0.000      -0.000      -0.000
# ==============================================================================
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            av_er_ratio   No. Observations:                   16
# Model:                            GLM   Df Residuals:                       15
# Model Family:                Gaussian   Df Model:                            0
# Link Function:                    log   Scale:                        0.050832
# Method:                          IRLS   Log-Likelihood:                 1.6308
# Date:                Mon, 03 May 2021   Deviance:                      0.76248
# Time:                        05:01:57   Pearson chi2:                    0.762
# No. Iterations:                     7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# end           -0.0008      0.000     -4.313      0.000      -0.001      -0.000
# ==============================================================================
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            av_er_ratio   No. Observations:                   24
# Model:                            GLM   Df Residuals:                       23
# Model Family:                Gaussian   Df Model:                            0
# Link Function:                    log   Scale:                        0.055352
# Method:                          IRLS   Log-Likelihood:                 1.1741
# Date:                Mon, 03 May 2021   Deviance:                       1.2731
# Time:                        05:01:57   Pearson chi2:                     1.27
# No. Iterations:                     7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# end           -0.0006      0.000     -5.048      0.000      -0.001      -0.000
# ==============================================================================
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            av_er_ratio   No. Observations:                   28
# Model:                            GLM   Df Residuals:                       27
# Model Family:                Gaussian   Df Model:                            0
# Link Function:                    log   Scale:                        0.031162
# Method:                          IRLS   Log-Likelihood:                 9.3297
# Date:                Mon, 03 May 2021   Deviance:                      0.84136
# Time:                        05:01:57   Pearson chi2:                    0.841
# No. Iterations:                     6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# end           -0.0003   5.69e-05     -5.854      0.000      -0.000      -0.000
# ==============================================================================
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            av_er_ratio   No. Observations:                   15
# Model:                            GLM   Df Residuals:                       14
# Model Family:                Gaussian   Df Model:                            0
# Link Function:                    log   Scale:                        0.066647
# Method:                          IRLS   Log-Likelihood:               -0.47153
# Date:                Mon, 03 May 2021   Deviance:                      0.93306
# Time:                        05:01:57   Pearson chi2:                    0.933
# No. Iterations:                    11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# end           -0.0022      0.000     -4.752      0.000      -0.003      -0.001
# ==============================================================================
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            av_er_ratio   No. Observations:                   28
# Model:                            GLM   Df Residuals:                       27
# Model Family:                Gaussian   Df Model:                            0
# Link Function:                    log   Scale:                        0.059870
# Method:                          IRLS   Log-Likelihood:                0.18786
# Date:                Mon, 03 May 2021   Deviance:                       1.6165
# Time:                        05:01:57   Pearson chi2:                     1.62
# No. Iterations:                     7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# end           -0.0004   8.23e-05     -4.566      0.000      -0.001      -0.000
# ==============================================================================
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            av_er_ratio   No. Observations:                   12
# Model:                            GLM   Df Residuals:                       11
# Model Family:                Gaussian   Df Model:                            0
# Link Function:                    log   Scale:                        0.070339
# Method:                          IRLS   Log-Likelihood:               -0.60067
# Date:                Mon, 03 May 2021   Deviance:                      0.77373
# Time:                        05:01:57   Pearson chi2:                    0.774
# No. Iterations:                     8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# end           -0.0013      0.000     -3.467      0.001      -0.002      -0.001
# ==============================================================================
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            av_er_ratio   No. Observations:                   42
# Model:                            GLM   Df Residuals:                       41
# Model Family:                Gaussian   Df Model:                            0
# Link Function:                    log   Scale:                        0.036474
# Method:                          IRLS   Log-Likelihood:                 10.439
# Date:                Mon, 03 May 2021   Deviance:                       1.4954
# Time:                        05:01:57   Pearson chi2:                     1.50
# No. Iterations:                     7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# end           -0.0002   3.38e-05     -6.623      0.000      -0.000      -0.000
# ==============================================================================
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            av_er_ratio   No. Observations:                   19
# Model:                            GLM   Df Residuals:                       18
# Model Family:                Gaussian   Df Model:                            0
# Link Function:                    log   Scale:                        0.043925
# Method:                          IRLS   Log-Likelihood:                 3.2303
# Date:                Mon, 03 May 2021   Deviance:                      0.79065
# Time:                        05:01:57   Pearson chi2:                    0.791
# No. Iterations:                     7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# end           -0.0006      0.000     -4.555      0.000      -0.001      -0.000
# ==============================================================================
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            av_er_ratio   No. Observations:                    9
# Model:                            GLM   Df Residuals:                        8
# Model Family:                Gaussian   Df Model:                            0
# Link Function:                    log   Scale:                        0.037152
# Method:                          IRLS   Log-Likelihood:                 2.5469
# Date:                Mon, 03 May 2021   Deviance:                      0.29721
# Time:                        05:01:57   Pearson chi2:                    0.297
# No. Iterations:                     7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# end           -0.0014      0.000     -3.842      0.000      -0.002      -0.001
# ==============================================================================
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            av_er_ratio   No. Observations:                    9
# Model:                            GLM   Df Residuals:                        8
# Model Family:                Gaussian   Df Model:                            0
# Link Function:                    log   Scale:                        0.041962
# Method:                          IRLS   Log-Likelihood:                 1.9991
# Date:                Mon, 03 May 2021   Deviance:                      0.33569
# Time:                        05:01:57   Pearson chi2:                    0.336
# No. Iterations:                     7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# end           -0.0012      0.000     -3.275      0.001      -0.002      -0.000
# ==============================================================================
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            av_er_ratio   No. Observations:                   12
# Model:                            GLM   Df Residuals:                       11
# Model Family:                Gaussian   Df Model:                            0
# Link Function:                    log   Scale:                        0.040546
# Method:                          IRLS   Log-Likelihood:                 2.7047
# Date:                Mon, 03 May 2021   Deviance:                      0.44600
# Time:                        05:01:57   Pearson chi2:                    0.446
# No. Iterations:                     7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# end           -0.0011      0.000     -4.267      0.000      -0.002      -0.001
# ==============================================================================
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:            av_er_ratio   No. Observations:                   15
# Model:                            GLM   Df Residuals:                       14
# Model Family:                Gaussian   Df Model:                            0
# Link Function:                    log   Scale:                        0.056539
# Method:                          IRLS   Log-Likelihood:                0.76216
# Date:                Mon, 03 May 2021   Deviance:                      0.79154
# Time:                        05:01:57   Pearson chi2:                    0.792
# No. Iterations:                     7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# end           -0.0009      0.000     -4.020      0.000      -0.001      -0.000
# ==============================================================================

# %%
import scipy.stats
r = []
p = []
for x in dl_er:
    if len(x)>8:
        x = x.drop(index=[len(x)-1])
        r1, p1 = scipy.stats.pearsonr(x['end'], x['av_er_ratio'])
        r.append(r1)
        p.append(p1)

print(p)
# Out:
# [0.0023184579904459994, 7.270111976230816e-05, 0.005844608372544808, 4.0128130326422105e-05, 8.094812576786696e-10, 3.1129801055696803e-06, 2.794180367533778e-09, 6.157054388215735e-09, 2.0637477242609566e-06, 0.3768136402207596, 0.014304941656989065, 2.3460703230912744e-05, 1.8996441703480584e-08, 0.01816317162428457, 2.2661090998820497e-10, 0.0032545707013734554, 2.0913257067153817e-08, 1.7849177363859966e-05, 0.008926404563796177, 0.00783486816508145, 3.853282170701565e-05, 2.3180700821517235e-05, 3.7726147184671255e-05, 9.076814216120271e-06, 2.9805368892443512e-05, 1.7800656544366519e-06, 2.9717165253506718e-08, 0.6194442805352715, 0.0020065841531459044, 2.6377316660581437e-13, 0.0011192245360288782, 0.1640587048238207, 1.6152828568262286e-10, 2.849176507817204e-06, 0.09460274624927995, 0.006780451389496892, 2.3541509623993007e-06, 0.031820526754389275, 0.00022460691895984068, 1.3927514173990955e-07, 1.0413499813806644e-09, 1.2476539565738752e-06, 1.2487429945853753e-05, 1.9619275568750988e-05, 0.0005608298884625044, 0.0021915606190336325, 0.019608623711061406, 4.768645387319298e-06, 1.8785787857080154e-05, 0.00041865256391525053, 0.0001820046141271509, 7.431836819504444e-08, 0.006022727477811059, 7.780072836491914e-09, 0.0006361411484067527, 0.00012137183260724565, 0.0002667099218996842, 8.429940751113483e-09, 0.01440649705666142, 6.9281475914736265e-09, 2.3689008600979585e-07, 0.00015037279714153102, 3.899303375486481e-08, 7.3052256945593604e-06, 0.0009926500258067995, 0.00017333115591857003, 0.0001920748530002067, 0.08262610643086421, 0.035983257391354745, 5.875930653411627e-06, 0.00010278717771924064, 0.009705478909071912, 2.5204458513752115e-06, 0.0009079432414292685, 0.019247142467606535, 1.616445151227796e-06, 2.1029998560337546e-06, 5.781650086886513e-05, 1.4787658754798305e-09, 8.574064454753814e-07, 0.00024264688600560835, 0.011902442258472192, 2.112144360176071e-09, 0.026971800534092927, 5.962808072833329e-05, 9.72077343302328e-12, 0.00049371066231003, 0.0008750211621302019, 0.00017151689112681256, 0.0013194077152228311, 1.397029845408804e-06, 0.0009235560228046453, 7.755119128586589e-08, 0.010904948538322471, 6.647086996064812e-20, 0.006032451469234258, 0.0010990783468708637, 0.0004054194372908663, 0.031221226350169135, 5.3793593683891465e-11, 1.1288832059222428e-06, 0.011988346401801834, 0.00037393557516400826, 0.03488223211967041, 1.6850909072138953e-07, 3.1650532453823173e-13, 0.0013052738742213923, 0.0004616606778747143, 4.447733284321014e-12, 3.2957592267302135e-06, 3.478341820565674e-11, 0.004535142226934956, 0.0072890257680407996, 6.183082418302604e-08, 0.017222877346197017, 0.0005554978363445617, 3.254688510164358e-09, 0.0067721059543918135, 0.013662315642916761, 9.878623100745542e-06, 1.1360239653501778e-09, 7.086752918982076e-11, 3.3341103938656625e-06, 0.007438685495780411, 0.00012601473926921185, 5.399879786382872e-07, 3.398380736568767e-11, 4.503221858845768e-07, 4.7480034967531035e-09, 0.00017891644971619068, 0.006189839269480712, 0.31298064132284076, 0.0036081695911539696, 1.0908100193180332e-05, 0.0007093551043127806, 0.00042986857089840784, 0.020708616165806944, 0.0019981164939518944, 1.4199007331223145e-06, 0.001413699723075662, 1.4860019293696777e-06, 1.1059888559743758e-07, 0.0017887844278374465, 9.775443360422715e-06, 5.7387139684212755e-05, 4.5762502680842976e-08, 0.0004535354993036928, 8.747026500367832e-05, 9.628322001483847e-05, 0.001088209360092687, 7.344184157833109e-05, 0.0037232402997925177, 2.7163452372690113e-05, 0.1094645081281964, 0.005218148921840971, 0.02060783999239346, 1.4921415870559112e-06, 8.604017312467438e-06, 0.01355135122017301, 0.03412878327226351, 8.720833184372311e-05, 9.540327767902644e-07, 5.120519688163813e-05, 0.026303850344256835, 2.4474134167292297e-09, 0.0012481725493388074, 0.003674063087818329, 0.00018294853124317404, 0.0033607292386123523, 8.35320382518523e-06, 0.030863721909454307, 5.94167045360638e-08, 0.0021578010362296547, 0.4472432716203164, 0.00015 ...
