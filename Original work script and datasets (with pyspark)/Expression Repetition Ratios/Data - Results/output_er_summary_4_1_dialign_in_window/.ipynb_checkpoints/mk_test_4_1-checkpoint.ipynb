# %%
import numpy as np
import pymannkendall as mk
import pandas as pd
import glob,os

# %%
er_file = glob.glob("S***.csv")

# %%
dl_er = []
out = []
for f in er_file:
    dl_er.append(pd.read_csv(f))

for x in dl_er:
    print(len(x))
    if len(x)>8:
        x = x.drop(index=[len(x)-1])
        out.append(mk.original_test(x['av_er_ratio']))
# Out:
# 61
# 8
# 76
# 29
# 12
# 14
# 37
# 12
# 62
# 5
# 26
# 15
# 10
# 8
# 46
# 35
# 12
# 12
# 8
# 6
# 8
# 21
# 25
# 15
# 35
# 20
# 33
# 39
# 27
# 8
# 6
# 37
# 9
# 6
# 26
# 4
# 14
# 29
# 86
# 41
# 30
# 15
# 11
# 19
# 18
# 24
# 9
# 16
# 26
# 8
# 28
# 11
# 24
# 36
# 38
# 13
# 9
# 27
# 14
# 42
# 27
# 7
# 47
# 17
# 25
# 5
# 27
# 30
# 11
# 12
# 17
# 57
# 16
# 17
# 23
# 20
# 21
# 6
# 23
# 65
# 7
# 15
# 32
# 58
# 32
# 76
# 13
# 8
# 64
# 30
# 36
# 10
# 19
# 12
# 32
# 58
# 26
# 63
# 5
# 32
# 29
# 50
# 47
# 13
# 66
# 313
# 29
# 16
# 66
# 6
# 11
# 10
# 31
# 22
# 16
# 48
# 6
# 31
# 23
# 37
# 43
# 65
# 11
# 22
# 7
# 23
# 25
# 19
# 24
# 17
# 43
# 8
# 31
# 16
# 38
# 10
# 24
# 50
# 10
# 23
# 24
# 4
# 43
# 25
# 7
# 42
# 5
# 11
# 15
# 31
# 30
# 10
# 9
# 15
# 49
# 4
# 19
# 31
# 12
# 31
# 61
# 9
# 23
# 5
# 8
# 18
# 17
# 51
# 6
# 101
# 10
# 21
# 11
# 17
# 14
# 10
# 17
# 41
# 31
# 10
# 14
# 12
# 13
# 40
# 15
# 12
# 39
# 22
# 10
# 5
# 16
# 47
# 20
# 39
# 39
# 9
# 49
# 9

# %%
print(len(dl_er))
print(len(out))
c = 0
for o in out:
    if o.trend == "increasing":
        c = c+1
print(c)
print(167/169)
# Out:
# 198
# 169
# 167
# 0.9881656804733728

# %%
df = pd.concat(dl_er)
df.to_csv('group4_summary.csv', index = False)

# %%
df_summary = pd.read_csv('group4_summary.csv')

# %%
print(df_summary)
# Out:
#      speaker1  speaker1_token_number  speaker1_expression_token_number  \
# 0       S0588                    109                                33
# 1       S0588                    133                                74
# 2       S0588                    101                                49
# 3       S0588                    121                                83
# 4       S0588                     29                                22
# ...       ...                    ...                               ...
# 5184    S0309                    308                               187
# 5185    S0309                    311                               222
# 5186    S0309                    114                                86
# 5187    S0309                    410                               313
# 5188    S0309                     53                                36
#
#       speaker1_expression_number  speaker1_er_ratio speaker2  \
# 0                             32           0.302752    S0590
# 1                             70           0.556391    S0590
# 2                             43           0.485149    S0590
# 3                             74           0.685950    S0590
# 4                             18           0.758621    S0590
# ...                          ...                ...      ...
# 5184                         167           0.607143    S0268
# 5185                         175           0.713826    S0268
# 5186                          69           0.754386    S0268
# 5187                         247           0.763415    S0268
# 5188                          31           0.679245    S0268
#
#       speaker2_token_number  speaker2_expression_token_number  \
# 0                       117                                62
# 1                       120                                78
# 2                       224                               139
# 3                       135                                98
# 4                       175                               125
# ...                     ...                               ...
# 5184                     40                                32
# 5185                    365                               294
# 5186                     50                                41
# 5187                     33                                29
# 5188                      2                                 2
#
#       speaker2_expression_number  speaker2_er_ratio  ...  \
# 0                             56           0.529915  ...
# 1                             69           0.650000  ...
# 2                            123           0.620536  ...
# 3                             84           0.725926  ...
# 4                            106           0.714286  ...
# ...                          ...                ...  ...
# 5184                          25           0.800000  ...
# 5185                         210           0.805479  ...
# 5186                          28           0.820000  ...
# 5187                          22           0.878788  ...
# 5188                           2           1.000000  ...
#
#      speaker4_expression_token_number  speaker4_expression_number  \
# 0                                   0                           0
# 1                                   3                           2
# 2                                   0                           0
# 3                                   0                           0
# 4                                   6                           5
# ...                               ...                         ...
# 5184                               44                          35
# 5185                               25                          18
# 5186                               27                          20
# 5187                               84                          58
# 5188                               24                          21
#
#       speaker4_er_ratio  total_token_number  total_er_token_number  \
# 0              0.000000                 226                     95
# 1              0.600000                 271                    160
# 2              0.000000                 325                    188
# 3              0.000000                 262                    184
# 4              0.750000                 313                    231
# ...                 ...                 ...                    ...
# 5184           0.830189                 544                    391
# 5185           0.806452                 721                    553
# 5186           0.750000                 582                    461
# 5187           0.903226                 565                    450
# 5188           0.888889                 127                     97
#
#      av_er_ratio  total_er_number  begin  end      file
# 0       0.420354               88      0   50  S263.tsv
# 1       0.590406              146     50  100  S263.tsv
# 2       0.578462              166    100  150  S263.tsv
# 3       0.702290              161    150  200  S263.tsv
# 4       0.738019              185    200  250  S263.tsv
# ...          ...              ...    ...  ...       ...
# 5184    0.718750              328    200  250  S9RV.tsv
# 5185    0.766990              412    250  300  S9RV.tsv
# 5186    0.792096              323    300  350  S9RV.tsv
# 5187    0.796460              344    350  400  S9RV.tsv
# 5188    0.763780               79    400  418  S9RV.tsv
#
# [5189 rows x 27 columns]

# %%
for i in range(0, len(df_summary)):
    if df_summary['end'].iloc[i]%50!=0:
        df_summary['av_er_ratio'].iloc[i] = None

df_summary = df_summary.dropna()

grouped_df = df_summary.groupby("end")
mean_df = grouped_df['av_er_ratio'].mean()

mean_df = mean_df.reset_index()
print(mean_df)
# Out:
#        end  av_er_ratio
# 0       50     0.340847
# 1      100     0.549817
# 2      150     0.631030
# 3      200     0.680452
# 4      250     0.717118
# ..     ...          ...
# 307  15400     0.958466
# 308  15450     0.904908
# 309  15500     0.936255
# 310  15550     0.932353
# 311  15600     0.975385
#
# [312 rows x 2 columns]
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
import matplotlib.pyplot as plt
l1=plt.plot(mean_df['end'],mean_df['av_er_ratio'],label='type1')
plt.title('The Average ER ratio at each position - 4 speakers - method1')
plt.xlabel('Position')
plt.ylabel('Average ER ratio')
# Out:
# Text(0, 0.5, 'Average ER ratio')
